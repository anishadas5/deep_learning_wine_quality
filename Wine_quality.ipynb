# %%
# import pandas
import pandas as pd

# import numpy
import numpy as np

# import seaborn
import seaborn as sns

# import matplotlib
import matplotlib.pyplot as plt

# %%
# creating Dataframe object
import os
working_directory=os.getcwd()
print (working_directory)
path=working_directory + '/winequality-white.csv'
df=pd.read_csv(path)
# Out:
# /Users/anisha/DL assignment

# %%
print(df.shape)
print(df.head())
print(df.info())
print(df.describe())
# Out:
# (4898, 12)
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB
# None
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# min       0.009000             2.000000              9.000000     0.987110
# 25%       0.036000            23.000000            108.000000     0.991723
# 50%       0.043000            34.000000            134.000000     0.993740
# 75%       0.050000            46.000000            167.000000     0.996100
# max       0.346000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  4898.000000  4898.000000  4898.000000  4898.000000
# mean      3.188267     0.489847    10.514267     5.877909
# std       0.151001     0.114126     1.230621     0.885639
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.090000     0.410000     9.500000     5.000000
# 50%       3.180000     0.470000    10.400000     6.000000
# 75%       3.280000     0.550000    11.400000     6.000000
# max       3.820000     1.080000    14.200000     9.000000

# %%
df.hist(bins=25,figsize=(10,10))
# display histogram
plt.show()

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# min       0.009000             2.000000              9.000000     0.987110
# 25%       0.036000            23.000000            108.000000     0.991723
# 50%       0.043000            34.000000            134.000000     0.993740
# 75%       0.050000            46.000000            167.000000     0.996100
# max       0.346000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  4898.000000  4898.000000  4898.000000  4898.000000
# mean      3.188267     0.489847    10.514267     5.877909
# std       0.151001     0.114126     1.230621     0.885639
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.090000     0.410000     9.500000     5.000000
# 50%       3.180000     0.470000    10.400000     6.000000
# 75%       3.280000     0.550000    11.400000     6.000000
# max       3.820000     1.080000    14.200000     9.000000

# %%
df.skew()
# Out:
# fixed acidity           0.647751
# volatile acidity        1.576980
# citric acid             1.281920
# residual sugar          1.077094
# chlorides               5.023331
# free sulfur dioxide     1.406745
# total sulfur dioxide    0.390710
# density                 0.977773
# pH                      0.457783
# sulphates               0.977194
# alcohol                 0.487342
# quality                 0.155796
# dtype: float64

# %%
df.hist(figsize=(15,15), layout=(4,4), bins=20)
# Out:
# array([[<AxesSubplot:title={'center':'fixed acidity'}>,
#         <AxesSubplot:title={'center':'volatile acidity'}>,
#         <AxesSubplot:title={'center':'citric acid'}>,
#         <AxesSubplot:title={'center':'residual sugar'}>],
#        [<AxesSubplot:title={'center':'chlorides'}>,
#         <AxesSubplot:title={'center':'free sulfur dioxide'}>,
#         <AxesSubplot:title={'center':'total sulfur dioxide'}>,
#         <AxesSubplot:title={'center':'density'}>],
#        [<AxesSubplot:title={'center':'pH'}>,
#         <AxesSubplot:title={'center':'sulphates'}>,
#         <AxesSubplot:title={'center':'alcohol'}>,
#         <AxesSubplot:title={'center':'quality'}>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]],
#       dtype=object)

# %%
df.plot(kind="box",subplots=True,layout=(5,5),figsize=(15,15))
# Out:
# fixed acidity              AxesSubplot(0.125,0.749828;0.133621x0.130172)
# volatile acidity        AxesSubplot(0.285345,0.749828;0.133621x0.130172)
# citric acid              AxesSubplot(0.44569,0.749828;0.133621x0.130172)
# residual sugar          AxesSubplot(0.606034,0.749828;0.133621x0.130172)
# chlorides               AxesSubplot(0.766379,0.749828;0.133621x0.130172)
# free sulfur dioxide        AxesSubplot(0.125,0.593621;0.133621x0.130172)
# total sulfur dioxide    AxesSubplot(0.285345,0.593621;0.133621x0.130172)
# density                  AxesSubplot(0.44569,0.593621;0.133621x0.130172)
# pH                      AxesSubplot(0.606034,0.593621;0.133621x0.130172)
# sulphates               AxesSubplot(0.766379,0.593621;0.133621x0.130172)
# alcohol                    AxesSubplot(0.125,0.437414;0.133621x0.130172)
# quality                 AxesSubplot(0.285345,0.437414;0.133621x0.130172)
# dtype: object

# %%
df.loc[df['citric acid']>1.1,'citric acid'] = np.mean(df["citric acid"])
df.loc[df['residual sugar']>60,'residual sugar'] = np.mean(df["residual sugar"])
df.loc[df['chlorides']>5.5,'chlorides'] = np.mean(df["chlorides"])
df.loc[df['free sulfur dioxide']>250,'free sulfur dioxide'] = np.mean(df["free sulfur dioxide"])
df.loc[df['total sulfur dioxide']>330,'total sulfur dioxide'] = np.mean(df["total sulfur dioxide"])
df.loc[df['density']>1.01,'density'] = np.mean(df["density"])

# %%
plt.figure(figsize=[14,6])
sns.heatmap(df.corr(), annot = True,cmap = 'coolwarm')
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x='quality', data=df)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %%
#get_dummies() function which is used for handling categorical columns, 
#in this dataset ‘Type’ feature contains two types Red and White,
#where Red consider as 0 and white considers as 1
df = pd.get_dummies(df,drop_first=True)
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# ...       ...      ...
# 4893     11.2        6
# 4894      9.6        5
# 4895      9.4        6
# 4896     12.8        7
# 4897     11.8        6
#
# [4898 rows x 12 columns]

# %%
# as we can see from the above table some wine quality of 6 and 5 is white and some as red
# considering the best quality value of wine is 7
df['Excellent quality'] = [ 1 if x>=7 else 0 for x in df.quality] 
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality  Excellent quality
# 0         8.8        6                  0
# 1         9.5        6                  0
# 2        10.1        6                  0
# 3         9.9        6                  0
# 4         9.9        6                  0
# ...       ...      ...                ...
# 4893     11.2        6                  0
# 4894      9.6        5                  0
# 4895      9.4        6                  0
# 4896     12.8        7                  1
# 4897     11.8        6                  0
#
# [4898 rows x 13 columns]

# %%
y = df['Excellent quality']
y
y.value_counts()
# Out:
# 0    3838
# 1    1060
# Name: Excellent quality, dtype: int64

# %%
x = df.drop(['quality','Excellent quality'], axis =1)
x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol
# 0         8.8
# 1         9.5
# 2        10.1
# 3         9.9
# 4         9.9
# ...       ...
# 4893     11.2
# 4894      9.6
# 4895      9.4
# 4896     12.8
# 4897     11.8
#
# [4898 rows x 11 columns]

# %%
# !pip install imblearn
from imblearn.combine import SMOTEENN
sn = SMOTEENN(random_state=0)
sn.fit(x,y)
x,y=sn.fit_resample(x,y)
# Out:
# Collecting imblearn
#   Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.8.0-py3-none-any.whl (206 kB)
#      |████████████████████████████████| 206 kB 1.4 MB/s eta 0:00:01
# Requirement already satisfied: joblib>=0.11 in /Users/anisha/opt/anaconda3/lib/python3.8/site-packages (from imbalanced-learn->imblearn) (0.17.0)
# Collecting scikit-learn>=0.24
#   Downloading scikit_learn-0.24.2-cp38-cp38-macosx_10_13_x86_64.whl (7.2 MB)
#      |████████████████████████████████| 7.2 MB 4.3 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.13.3 in /Users/anisha/opt/anaconda3/lib/python3.8/site-packages (from imbalanced-learn->imblearn) (1.19.2)
# Requirement already satisfied: scipy>=0.19.1 in /Users/anisha/opt/anaconda3/lib/python3.8/site-packages (from imbalanced-learn->imblearn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/anisha/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.24->imbalanced-learn->imblearn) (2.1.0)
# Installing collected packages: scikit-learn, imbalanced-learn, imblearn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.23.2
#     Uninstalling scikit-learn-0.23.2:
#       Successfully uninstalled scikit-learn-0.23.2
# Successfully installed imbalanced-learn-0.8.0 imblearn-0.0 scikit-learn-0.24.2

# %%
y.value_counts()
# Out:
# 1    3285
# 0    2423
# Name: Excellent quality, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier
model1 = KNeighborsClassifier(n_neighbors=3)
model1.fit(x_train,y_train)
y_pred1 = model1.predict(x_test)

from sklearn.metrics import accuracy_score
print("Accuracy Score of KNN:",accuracy_score(y_test,y_pred1))
# Out:
# Accuracy Score of KNN: 0.9728546409807356

# %%
# importing modules
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import classification_report
#creating RandomForestClassifier constructor
model4 = RandomForestClassifier(random_state=1)
model4.fit(x_train, y_train)
y_pred4 = model4.predict(x_test)

print("Accuracy Score:",accuracy_score(y_test,y_pred4))
# display error rate
print('calculating the error')
# calculating mean squared error
MSE = np.square(np.subtract(y_test,y_pred4)).mean() 
# calculating root mean squared error
RMSE = np.sqrt(MSE)
# display MSE
print('mean squared error is : ',MSE)
# display RMSE
print('root mean squared error is : ',RMSE)
# Out:
# Accuracy Score: 0.9605954465849387
# calculating the error
# mean squared error is :  0.03940455341506129
# root mean squared error is :  0.19850580196825807
